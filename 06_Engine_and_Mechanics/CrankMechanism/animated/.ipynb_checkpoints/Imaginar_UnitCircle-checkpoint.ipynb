# %%
import numpy as np
import matplotlib.pyplot as plt
import time
from IPython.display import clear_output

# %%
n = 100
for k in range(0,n):
    time.sleep(0.7)
    clear_output(wait=True)
    plt.figure(figsize=(6,6)) #Size of GRAPH
    z = np.e**(2*np.pi*1j*k/n)+np.e**(4*np.pi*1j*k/n) #imaginary numbers in python is not i but j
    plt.plot([0,np.imag(z)],[0,np.real(z)], linewidth=7)
    x = np.linspace(0,2*np.pi,100) #code ofr circel (also best loop ever)
    plt.plot(np.cos(x), np.sin(x), 'r', linewidth = 5) #code for circle
    print(np.imag(z), np.real(z))
    plt.grid(alpha= 0.5)
    plt.style.use("dark_background") #background
    plt.xlim([-5, 5])
    plt.ylim([-5, 5])
    plt.show()
# Out:
# -0.18812375309361729 1.9901414297427493

# %%
fig, ax = plt.subplots(figsize=(12, 6))

a = np.arange(0, 10, 0.1)
b = np.sin(x)
c = np.cos(x)

ax.plot(b, color='blue', label='Sine wave')
ax.plot(c, color='red', label='Cosine wave')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

x = np.arange(0, 5, 0.01)

z1 = np.e**(x*2*np.pi*1j*k/n)
z2 = (np.e**(x*2*4*np.pi*1j*k/n))*np.e**(-0.8*x) 

z3 = z1 + z2

z_r1 = np.real(z1)
z_i1 = np.imag(z1)

z_r2 = np.real(z2)
z_i2 = np.imag(z2)

z_r3 = np.real(z3)
z_i3 = np.imag(z3)

ax.plot(z_r3, color='blue', label='Sine wave')
ax.plot(z_i3, color='red', label='Cosine wave')

#ax.plot(z_i1, color='white', label='Sine wave')
#ax.plot(z_i2, color='green', label='Cosine wave')


plt.show()

# %%
z3
# Out:
# array([ 2.00000000e+00+0.j        ,  1.99033740e+00+0.18624984j,
#         1.96147654e+00+0.3703412j ,  1.91379638e+00+0.55014619j,
#         1.84792228e+00+0.7235976j ,  1.76471679e+00+0.88871812j,
#         1.66526689e+00+1.04364818j,  1.55086800e+00+1.18667198j,
#         1.42300484e+00+1.31624144j,  1.28332963e+00+1.43099753j,
#         1.13363777e+00+1.52978878j,  9.75841508e-01+1.61168672j,
#         8.11941920e-01+1.67599784j,  6.43999702e-01+1.72227217j,
#         4.74105121e-01+1.75030809j,  3.04347673e-01+1.76015345j,
#         1.36785855e-01+1.75210302j, -2.65824604e-02+1.72669215j,
#        -1.83848622e-01+1.68468694j, -3.33220314e-01+1.62707092j,
#        -4.73046789e-01+1.5550286j , -6.01841842e-01+1.469926j  ,
#        -7.18304168e-01+1.37328854j, -8.21334813e-01+1.26677668j,
#        -9.10051443e-01+1.15215961j, -9.83799243e-01+1.03128739j,
#        -1.04215826e+00+0.9060621j , -1.08494711e+00+0.77840826j,
# ...
