# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
time = np.arange(0,2*math.pi,math.pi/20)
#the  dividing is maeking the wave more smooth, when bigger value

# %%
amplitude = np.sin(time)

# %%
plt.plot(time, amplitude)
plt.show()
